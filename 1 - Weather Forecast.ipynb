# %% [markdown]
# # Weather Forecast with PixieDust
#
# This notebook shows how to:
# 1. use the Weather Company Data API to get weather forecast json data based on latitude and longitude
# 2. convert this json data into a [pandas](http://pandas.pydata.org/pandas-docs/stable/) DataFrame
# 4. create a weather chart and map with [matplotlib](http://matplotlib.org/)
# 3. create a weather chart and map with [PixieDust](https://ibm-cds-labs.github.io/pixiedust/index.html)
#
# Before running the notebook:
# * Sign up for a free 30-day trial [Bluemix account](https://console.ng.bluemix.net/)
# * Launch the Weather Data service in Bluemix and fill in the credentials below. Learn more [here](https://console.ng.bluemix.net/docs/services/Weather/index.html)
# * Run this notebook locally or in the Cloud using the [IBM Data Science Experience](http://datascience.ibm.com/)
#
# ## 1. Load and install packages
#
# First, uncomment the lines in the below cell and upgrade the pixiedust and bokeh packages. When this is done restart the kernel. You have to do this only once, or when there is an update available.
#
# Then import the package needed to run this notebook.

# %%
#!pip install --upgrade pixiedust
#!pip install --upgrade bokeh

# %%
import requests
import json
import pandas as pd
import numpy as np
from datetime import datetime
import time
import pixiedust

pixiedust.enableSparkJobProgressMonitor()
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-cds-labs/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.0.4</span>
#         </div>
# Succesfully enabled Spark Job Progress Monitor

# %% [markdown]
# ## 2. Get weather data
#
# Find the latitude and longitude of your current location by running this magic javascript cell. Then fill in your Weather Company API credentials to load the weather forecast for where you are.

# %%
# %%javascript
# navigator.geolocation.getCurrentPosition(function(position) {
#   console.log(position.coords.latitude, position.coords.longitude);
# setTimeout(function() {
# IPython.notebook.kernel.execute('lat="' + position.coords.latitude + '";')
# IPython.notebook.kernel.execute('lon="' + position.coords.longitude + '";')
# },5000)});
# Out:
# <div id="pm_overallContainer0fcfd851" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie0fcfd851" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName0fcfd851"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress0fcfd851" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container0fcfd851" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors0fcfd851">
#     </ul>
#     <div class="tab-content" id="tabContent0fcfd851">
#     </div>
# </div>
#
# <script>
# $("#twistie0fcfd851").click(function(){
#     visible = $("#pm_container0fcfd851").is(':visible');
#     $("#pm_container0fcfd851").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %% [markdown]
# Wait a few seconds to run the second cell to allow the above geolocation function to run.

# %%
print(lat, lon)
# Out:
# <div id="pm_overallContainerdbc7dd91" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiedbc7dd91" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamedbc7dd91"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressdbc7dd91" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerdbc7dd91" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsdbc7dd91">
#     </ul>
#     <div class="tab-content" id="tabContentdbc7dd91">
#     </div>
# </div>
#
# <script>
# $("#twistiedbc7dd91").click(function(){
#     visible = $("#pm_containerdbc7dd91").is(':visible');
#     $("#pm_containerdbc7dd91").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
# ('51.450620099999995', '-2.5821595')

# %%
# @hidden_cell
# Weather company data API credentials
username='6b8a7a9f-919b-4018-bed1-2855844b5c0e'
password='AGu5QiArJF'
# Out:
# <div id="pm_overallContainer669fc926" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie669fc926" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName669fc926"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress669fc926" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container669fc926" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors669fc926">
#     </ul>
#     <div class="tab-content" id="tabContent669fc926">
#     </div>
# </div>
#
# <script>
# $("#twistie669fc926").click(function(){
#     visible = $("#pm_container669fc926").is(':visible');
#     $("#pm_container669fc926").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %%
line='https://'+username+':'+password+\
    '@twcservice.mybluemix.net/api/weather/v1/geocode/'+\
    lat+'/'+lon+'/forecast/intraday/10day.json?&units=m'
r=requests.get(line)
weather = json.loads(r.text)
# Out:
# <div id="pm_overallContainerb047901a" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistieb047901a" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNameb047901a"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressb047901a" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerb047901a" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsb047901a">
#     </ul>
#     <div class="tab-content" id="tabContentb047901a">
#     </div>
# </div>
#
# <script>
# $("#twistieb047901a").click(function(){
#     visible = $("#pm_containerb047901a").is(':visible');
#     $("#pm_containerb047901a").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %%
print json.dumps(weather, indent=4, sort_keys=True)
# Out:
# <div id="pm_overallContainer0f97fa31" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie0f97fa31" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName0f97fa31"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress0f97fa31" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container0f97fa31" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors0f97fa31">
#     </ul>
#     <div class="tab-content" id="tabContent0f97fa31">
#     </div>
# </div>
#
# <script>
# $("#twistie0f97fa31").click(function(){
#     visible = $("#pm_container0f97fa31").is(':visible');
#     $("#pm_container0f97fa31").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
# {
#     "forecasts": [
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 91,
#             "daypart_name": "Morning",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493359200,
#             "fcst_valid_local": "2017-04-28T07:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "num": 1,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 32,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 70,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 289,
#             "wdir_cardinal": "WNW",
#             "wspd": 10
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 70,
#             "daypart_name": "Afternoon",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493380800,
#             "fcst_valid_local": "2017-04-28T13:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 2,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": "A few sprinkles possible.",
#             "qualifier_code": null,
#             "rh": 66,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 267,
#             "wdir_cardinal": "W",
#             "wspd": 19
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 22,
#             "daypart_name": "Evening",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493402400,
#             "fcst_valid_local": "2017-04-28T19:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 3,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 75,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "wdir": 258,
#             "wdir_cardinal": "WSW",
#             "wspd": 17
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 16,
#             "daypart_name": "Overnight",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493424000,
#             "fcst_valid_local": "2017-04-29T01:00:00+0100",
#             "icon_code": 33,
#             "icon_extd": 3300,
#             "num": 4,
#             "phrase_12char": "M Clear",
#             "phrase_22char": "Mostly Clear",
#             "phrase_32char": "Mostly Clear",
#             "pop": 8,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 85,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Clear",
#             "subphrase_pt3": "",
#             "temp": 5,
#             "wdir": 209,
#             "wdir_cardinal": "SSW",
#             "wspd": 7
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 51,
#             "daypart_name": "Morning",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493445600,
#             "fcst_valid_local": "2017-04-29T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 5,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": "Turning warmer.",
#             "qualifier_code": null,
#             "rh": 70,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 170,
#             "wdir_cardinal": "S",
#             "wspd": 15
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 77,
#             "daypart_name": "Afternoon",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493467200,
#             "fcst_valid_local": "2017-04-29T13:00:00+0100",
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "num": 6,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 1,
#             "precip_type": "rain",
#             "qualifier": "Turning warmer.",
#             "qualifier_code": null,
#             "rh": 55,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 14,
#             "wdir": 167,
#             "wdir_cardinal": "SSE",
#             "wspd": 19
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 55,
#             "daypart_name": "Evening",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493488800,
#             "fcst_valid_local": "2017-04-29T19:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 7,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 13,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 68,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 128,
#             "wdir_cardinal": "SE",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 64,
#             "daypart_name": "Overnight",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493510400,
#             "fcst_valid_local": "2017-04-30T01:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "num": 8,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 32,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 71,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 124,
#             "wdir_cardinal": "SE",
#             "wspd": 27
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 95,
#             "daypart_name": "Morning",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493532000,
#             "fcst_valid_local": "2017-04-30T07:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1201,
#             "num": 9,
#             "phrase_12char": "Light Rain",
#             "phrase_22char": "Light Rain",
#             "phrase_32char": "Light Rain",
#             "pop": 79,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 75,
#             "subphrase_pt1": "Light",
#             "subphrase_pt2": "Rain",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 131,
#             "wdir_cardinal": "SE",
#             "wspd": 27
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 99,
#             "daypart_name": "Afternoon",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493553600,
#             "fcst_valid_local": "2017-04-30T13:00:00+0100",
#             "icon_code": 12,
#             "icon_extd": 1200,
#             "num": 10,
#             "phrase_12char": "Rain",
#             "phrase_22char": "Rain",
#             "phrase_32char": "Rain",
#             "pop": 89,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 77,
#             "subphrase_pt1": "Rain",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 151,
#             "wdir_cardinal": "SSE",
#             "wspd": 26
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 97,
#             "daypart_name": "Evening",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493575200,
#             "fcst_valid_local": "2017-04-30T19:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1201,
#             "num": 11,
#             "phrase_12char": "Light Rain",
#             "phrase_22char": "Light Rain",
#             "phrase_32char": "Light Rain",
#             "pop": 68,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 87,
#             "subphrase_pt1": "Light",
#             "subphrase_pt2": "Rain",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 232,
#             "wdir_cardinal": "SW",
#             "wspd": 11
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 90,
#             "daypart_name": "Overnight",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493596800,
#             "fcst_valid_local": "2017-05-01T01:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "num": 12,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 43,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 86,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "wdir": 258,
#             "wdir_cardinal": "WSW",
#             "wspd": 16
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 59,
#             "daypart_name": "Morning",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493618400,
#             "fcst_valid_local": "2017-05-01T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 13,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 15,
#             "precip_type": "rain",
#             "qualifier": "A stray shower or thunderstorm is possible.",
#             "qualifier_code": null,
#             "rh": 72,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 274,
#             "wdir_cardinal": "W",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 30,
#             "daypart_name": "Afternoon",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493640000,
#             "fcst_valid_local": "2017-05-01T13:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 14,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 11,
#             "precip_type": "rain",
#             "qualifier": "A stray shower or thunderstorm is possible.",
#             "qualifier_code": null,
#             "rh": 56,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 259,
#             "wdir_cardinal": "W",
#             "wspd": 23
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 14,
#             "daypart_name": "Evening",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493661600,
#             "fcst_valid_local": "2017-05-01T19:00:00+0100",
#             "icon_code": 31,
#             "icon_extd": 3100,
#             "num": 15,
#             "phrase_12char": "Clear",
#             "phrase_22char": "Clear",
#             "phrase_32char": "Clear",
#             "pop": 13,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 73,
#             "subphrase_pt1": "Clear",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 243,
#             "wdir_cardinal": "WSW",
#             "wspd": 15
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 21,
#             "daypart_name": "Overnight",
#             "dow": "Tuesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493683200,
#             "fcst_valid_local": "2017-05-02T01:00:00+0100",
#             "icon_code": 33,
#             "icon_extd": 3300,
#             "num": 16,
#             "phrase_12char": "M Clear",
#             "phrase_22char": "Mostly Clear",
#             "phrase_32char": "Mostly Clear",
#             "pop": 13,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 82,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Clear",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "wdir": 324,
#             "wdir_cardinal": "NW",
#             "wspd": 5
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 23,
#             "daypart_name": "Morning",
#             "dow": "Tuesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493704800,
#             "fcst_valid_local": "2017-05-02T07:00:00+0100",
#             "icon_code": 34,
#             "icon_extd": 3400,
#             "num": 17,
#             "phrase_12char": "M Sunny",
#             "phrase_22char": "Mostly Sunny",
#             "phrase_32char": "Mostly Sunny",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 76,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Sunny",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 42,
#             "wdir_cardinal": "NE",
#             "wspd": 7
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 37,
#             "daypart_name": "Afternoon",
#             "dow": "Tuesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493726400,
#             "fcst_valid_local": "2017-05-02T13:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 18,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 11,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 59,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 16,
#             "wdir": 0,
#             "wdir_cardinal": "N",
#             "wspd": 11
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 20,
#             "daypart_name": "Evening",
#             "dow": "Tuesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493748000,
#             "fcst_valid_local": "2017-05-02T19:00:00+0100",
#             "icon_code": 33,
#             "icon_extd": 3300,
#             "num": 19,
#             "phrase_12char": "M Clear",
#             "phrase_22char": "Mostly Clear",
#             "phrase_32char": "Mostly Clear",
#             "pop": 6,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 74,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Clear",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 23,
#             "wdir_cardinal": "NNE",
#             "wspd": 10
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 30,
#             "daypart_name": "Overnight",
#             "dow": "Wednesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493769600,
#             "fcst_valid_local": "2017-05-03T01:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 20,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 87,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 58,
#             "wdir_cardinal": "ENE",
#             "wspd": 12
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 37,
#             "daypart_name": "Morning",
#             "dow": "Wednesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493791200,
#             "fcst_valid_local": "2017-05-03T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 21,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 78,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 64,
#             "wdir_cardinal": "ENE",
#             "wspd": 21
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 69,
#             "daypart_name": "Afternoon",
#             "dow": "Wednesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493812800,
#             "fcst_valid_local": "2017-05-03T13:00:00+0100",
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "num": 22,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 1,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 55,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 16,
#             "wdir": 58,
#             "wdir_cardinal": "ENE",
#             "wspd": 21
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 29,
#             "daypart_name": "Evening",
#             "dow": "Wednesday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493834400,
#             "fcst_valid_local": "2017-05-03T19:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 23,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 5,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 65,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 54,
#             "wdir_cardinal": "NE",
#             "wspd": 18
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 8,
#             "daypart_name": "Overnight",
#             "dow": "Thursday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493856000,
#             "fcst_valid_local": "2017-05-04T01:00:00+0100",
#             "icon_code": 31,
#             "icon_extd": 3100,
#             "num": 24,
#             "phrase_12char": "Clear",
#             "phrase_22char": "Clear",
#             "phrase_32char": "Clear",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 82,
#             "subphrase_pt1": "Clear",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "wdir": 55,
#             "wdir_cardinal": "NE",
#             "wspd": 17
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 15,
#             "daypart_name": "Morning",
#             "dow": "Thursday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493877600,
#             "fcst_valid_local": "2017-05-04T07:00:00+0100",
#             "icon_code": 32,
#             "icon_extd": 3200,
#             "num": 25,
#             "phrase_12char": "Sunny",
#             "phrase_22char": "Sunny",
#             "phrase_32char": "Sunny",
#             "pop": 7,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 74,
#             "subphrase_pt1": "Sunny",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 65,
#             "wdir_cardinal": "ENE",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 36,
#             "daypart_name": "Afternoon",
#             "dow": "Thursday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493899200,
#             "fcst_valid_local": "2017-05-04T13:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 26,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 1,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 56,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 16,
#             "wdir": 72,
#             "wdir_cardinal": "ENE",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 25,
#             "daypart_name": "Evening",
#             "dow": "Thursday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493920800,
#             "fcst_valid_local": "2017-05-04T19:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 27,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 4,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 65,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 69,
#             "wdir_cardinal": "ENE",
#             "wspd": 21
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 20,
#             "daypart_name": "Overnight",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493942400,
#             "fcst_valid_local": "2017-05-05T01:00:00+0100",
#             "icon_code": 33,
#             "icon_extd": 3300,
#             "num": 28,
#             "phrase_12char": "M Clear",
#             "phrase_22char": "Mostly Clear",
#             "phrase_32char": "Mostly Clear",
#             "pop": 12,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 77,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Clear",
#             "subphrase_pt3": "",
#             "temp": 8,
#             "wdir": 64,
#             "wdir_cardinal": "ENE",
#             "wspd": 18
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 44,
#             "daypart_name": "Morning",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493964000,
#             "fcst_valid_local": "2017-05-05T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 29,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 12,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 72,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 71,
#             "wdir_cardinal": "ENE",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 75,
#             "daypart_name": "Afternoon",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1493985600,
#             "fcst_valid_local": "2017-05-05T13:00:00+0100",
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "num": 30,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 12,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 58,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 15,
#             "wdir": 78,
#             "wdir_cardinal": "ENE",
#             "wspd": 24
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 76,
#             "daypart_name": "Evening",
#             "dow": "Friday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494007200,
#             "fcst_valid_local": "2017-05-05T19:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 4600,
#             "num": 31,
#             "phrase_12char": "Few Showers",
#             "phrase_22char": "Few Showers",
#             "phrase_32char": "Few Showers",
#             "pop": 35,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 69,
#             "subphrase_pt1": "Few",
#             "subphrase_pt2": "Showers",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 69,
#             "wdir_cardinal": "ENE",
#             "wspd": 21
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 85,
#             "daypart_name": "Overnight",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494028800,
#             "fcst_valid_local": "2017-05-06T01:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "num": 32,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 40,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 85,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 9,
#             "wdir": 56,
#             "wdir_cardinal": "NE",
#             "wspd": 20
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 85,
#             "daypart_name": "Morning",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494050400,
#             "fcst_valid_local": "2017-05-06T07:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "num": 33,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 40,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 78,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 11,
#             "wdir": 61,
#             "wdir_cardinal": "ENE",
#             "wspd": 22
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 82,
#             "daypart_name": "Afternoon",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494072000,
#             "fcst_valid_local": "2017-05-06T13:00:00+0100",
#             "icon_code": 26,
#             "icon_extd": 2600,
#             "num": 34,
#             "phrase_12char": "Cloudy",
#             "phrase_22char": "Cloudy",
#             "phrase_32char": "Cloudy",
#             "pop": 16,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 60,
#             "subphrase_pt1": "Cloudy",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 15,
#             "wdir": 67,
#             "wdir_cardinal": "ENE",
#             "wspd": 21
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 67,
#             "daypart_name": "Evening",
#             "dow": "Saturday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494093600,
#             "fcst_valid_local": "2017-05-06T19:00:00+0100",
#             "icon_code": 27,
#             "icon_extd": 2700,
#             "num": 35,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 16,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 67,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 65,
#             "wdir_cardinal": "ENE",
#             "wspd": 16
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 54,
#             "daypart_name": "Overnight",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494115200,
#             "fcst_valid_local": "2017-05-07T01:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 36,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 9,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 81,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 57,
#             "wdir_cardinal": "ENE",
#             "wspd": 11
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 60,
#             "daypart_name": "Morning",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494136800,
#             "fcst_valid_local": "2017-05-07T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 37,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 10,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 75,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 36,
#             "wdir_cardinal": "NE",
#             "wspd": 13
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 75,
#             "daypart_name": "Afternoon",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494158400,
#             "fcst_valid_local": "2017-05-07T13:00:00+0100",
#             "icon_code": 28,
#             "icon_extd": 2800,
#             "num": 38,
#             "phrase_12char": "M Cloudy",
#             "phrase_22char": "Mostly Cloudy",
#             "phrase_32char": "Mostly Cloudy",
#             "pop": 10,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 59,
#             "subphrase_pt1": "Mostly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 17,
#             "wdir": 56,
#             "wdir_cardinal": "NE",
#             "wspd": 15
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 70,
#             "daypart_name": "Evening",
#             "dow": "Sunday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494180000,
#             "fcst_valid_local": "2017-05-07T19:00:00+0100",
#             "icon_code": 11,
#             "icon_extd": 1100,
#             "num": 39,
#             "phrase_12char": "Showers",
#             "phrase_22char": "Showers",
#             "phrase_32char": "Showers",
#             "pop": 42,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 71,
#             "subphrase_pt1": "Showers",
#             "subphrase_pt2": "",
#             "subphrase_pt3": "",
#             "temp": 14,
#             "wdir": 75,
#             "wdir_cardinal": "ENE",
#             "wspd": 14
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 39,
#             "daypart_name": "Overnight",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494201600,
#             "fcst_valid_local": "2017-05-08T01:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 40,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 8,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 76,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 10,
#             "wdir": 63,
#             "wdir_cardinal": "ENE",
#             "wspd": 13
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 32,
#             "daypart_name": "Morning",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494223200,
#             "fcst_valid_local": "2017-05-08T07:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 41,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 20,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 72,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 12,
#             "wdir": 73,
#             "wdir_cardinal": "ENE",
#             "wspd": 14
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 43,
#             "daypart_name": "Afternoon",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494244800,
#             "fcst_valid_local": "2017-05-08T13:00:00+0100",
#             "icon_code": 30,
#             "icon_extd": 3000,
#             "num": 42,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 14,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 58,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 16,
#             "wdir": 88,
#             "wdir_cardinal": "E",
#             "wspd": 15
#         },
#         {
#             "class": "fod_long_range_intraday",
#             "clds": 47,
#             "daypart_name": "Evening",
#             "dow": "Monday",
#             "expire_time_gmt": 1493375209,
#             "fcst_valid": 1494266400,
#             "fcst_valid_local": "2017-05-08T19:00:00+0100",
#             "icon_code": 29,
#             "icon_extd": 2900,
#             "num": 43,
#             "phrase_12char": "P Cloudy",
#             "phrase_22char": "Partly Cloudy",
#             "phrase_32char": "Partly Cloudy",
#             "pop": 6,
#             "precip_type": "rain",
#             "qualifier": null,
#             "qualifier_code": null,
#             "rh": 68,
#             "subphrase_pt1": "Partly",
#             "subphrase_pt2": "Cloudy",
#             "subphrase_pt3": "",
#             "temp": 13,
#             "wdir": 87,
#             "wdir_cardinal": "E",
#             "wspd": 14
#         }
#     ],
#     "metadata": {
#         "expire_time_gmt": 1493375209,
#         "language": "en-US",
#         "latitude": 51.45,
#         "longitude": -2.58,
#         "status_code": 200,
#         "transaction_id": "1493374316914:2043070018",
#         "units": "m",
#         "version": "1"
#     }
# }

# %% [markdown]
# ## 3. Convert json data to pandas DataFrame
#
# Convert the data into a DataFrame with each timestep on a new row. Convert the timestamp into a datetime format and drop the columns that are not needed. See this [Cheat sheet](http://www.saltycrane.com/blog/2008/11/python-datetime-time-conversions/) for date format conversions. Finally, convert the data type into numeric.

# %%
df = pd.DataFrame.from_dict(weather['forecasts'][0],orient='index').transpose()
for forecast in weather['forecasts'][1:]:
    df = pd.concat([df, pd.DataFrame.from_dict(forecast,orient='index').transpose()])

df['date'] = df['fcst_valid_local'].apply(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S+0100'))

df = df.drop(['expire_time_gmt','num','qualifier','qualifier_code'],1)   
df = df.drop(['fcst_valid','fcst_valid_local','icon_extd','wdir_cardinal'],1)   
df = df.drop(['subphrase_pt1','subphrase_pt2','subphrase_pt3','class'],1)   
df = df.drop(['daypart_name','phrase_12char','phrase_22char','phrase_32char'],1)   

df.dtypes
# Out:
# <div id="pm_overallContainer3c9926fb" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie3c9926fb" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName3c9926fb"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress3c9926fb" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container3c9926fb" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors3c9926fb">
#     </ul>
#     <div class="tab-content" id="tabContent3c9926fb">
#     </div>
# </div>
#
# <script>
# $("#twistie3c9926fb").click(function(){
#     visible = $("#pm_container3c9926fb").is(':visible');
#     $("#pm_container3c9926fb").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
# pop                    object
# wspd                   object
# rh                     object
# icon_code              object
# clds                   object
# wdir                   object
# temp                   object
# precip_type            object
# dow                    object
# date           datetime64[ns]
# dtype: object

# %%
df[['pop','wspd','rh','clds','wdir','temp']] = df[['pop','wspd','rh','clds','wdir','temp']].apply(pd.to_numeric)
df.dtypes
# Out:
# <div id="pm_overallContainerbb7c703f" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiebb7c703f" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamebb7c703f"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressbb7c703f" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerbb7c703f" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsbb7c703f">
#     </ul>
#     <div class="tab-content" id="tabContentbb7c703f">
#     </div>
# </div>
#
# <script>
# $("#twistiebb7c703f").click(function(){
#     visible = $("#pm_containerbb7c703f").is(':visible');
#     $("#pm_containerbb7c703f").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
# pop                     int64
# wspd                    int64
# rh                      int64
# icon_code              object
# clds                    int64
# wdir                    int64
# temp                    int64
# precip_type            object
# dow                    object
# date           datetime64[ns]
# dtype: object

# %% [markdown]
# As there seems to be an issue with the `pop` column (percentage of precipitation), create a new column rain. For the charts calculate some rolling means.

# %%
df['rain'] = df['pop'].as_matrix()
df=df.drop('pop',1)
# Out:
# <div id="pm_overallContainer9e45bcab" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie9e45bcab" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName9e45bcab"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress9e45bcab" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container9e45bcab" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors9e45bcab">
#     </ul>
#     <div class="tab-content" id="tabContent9e45bcab">
#     </div>
# </div>
#
# <script>
# $("#twistie9e45bcab").click(function(){
#     visible = $("#pm_container9e45bcab").is(':visible');
#     $("#pm_container9e45bcab").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %%
df.head()
# Out:
# <div id="pm_overallContainer283cacad" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie283cacad" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName283cacad"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress283cacad" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container283cacad" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors283cacad">
#     </ul>
#     <div class="tab-content" id="tabContent283cacad">
#     </div>
# </div>
#
# <script>
# $("#twistie283cacad").click(function(){
#     visible = $("#pm_container283cacad").is(':visible');
#     $("#pm_container283cacad").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
#    wspd  rh icon_code  clds  wdir  temp precip_type       dow  \
# 0    10  70        11    91   289    11        rain    Friday
# 0    19  66        30    70   267    12        rain    Friday
# 0    17  75        29    22   258     9        rain    Friday
# 0     7  85        33    16   209     5        rain  Saturday
# 0    15  70        30    51   170    10        rain  Saturday
#
#                  date  rain
# 0 2017-04-28 07:00:00    32
# 0 2017-04-28 13:00:00     7
# 0 2017-04-28 19:00:00     7
# 0 2017-04-29 01:00:00     8
# 0 2017-04-29 07:00:00     7

# %% [markdown]
# ## 4. Plot data with matplotlib

# %%
df = df.set_index('date',drop=False)
df.head()
# Out:
# <div id="pm_overallContainer40435371" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie40435371" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName40435371"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress40435371" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container40435371" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors40435371">
#     </ul>
#     <div class="tab-content" id="tabContent40435371">
#     </div>
# </div>
#
# <script>
# $("#twistie40435371").click(function(){
#     visible = $("#pm_container40435371").is(':visible');
#     $("#pm_container40435371").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
#                      wspd  rh icon_code  clds  wdir  temp precip_type  \
# date
# 2017-04-28 07:00:00    10  70        11    91   289    11        rain
# 2017-04-28 13:00:00    19  66        30    70   267    12        rain
# 2017-04-28 19:00:00    17  75        29    22   258     9        rain
# 2017-04-29 01:00:00     7  85        33    16   209     5        rain
# 2017-04-29 07:00:00    15  70        30    51   170    10        rain
#
#                           dow                date  rain
# date
# 2017-04-28 07:00:00    Friday 2017-04-28 07:00:00    32
# 2017-04-28 13:00:00    Friday 2017-04-28 13:00:00     7
# 2017-04-28 19:00:00    Friday 2017-04-28 19:00:00     7
# 2017-04-29 01:00:00  Saturday 2017-04-29 01:00:00     8
# 2017-04-29 07:00:00  Saturday 2017-04-29 07:00:00     7

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(14, 8))

df['temp'].plot(ax=axes[1], color='#6EEDD8',lw=3.0,sharex=True)
axes[1].set_title('Temperature',loc='left',fontsize=20)

df['rain'].plot(ax=axes[0], kind='bar', color='#C93D79',lw=2.0,sharex=True)
axes[0].set_title('Chance of rain',loc='left',fontsize=20)
# Out:
# <div id="pm_overallContainerdfa20370" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistiedfa20370" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamedfa20370"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressdfa20370" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerdfa20370" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsdfa20370">
#     </ul>
#     <div class="tab-content" id="tabContentdfa20370">
#     </div>
# </div>
#
# <script>
# $("#twistiedfa20370").click(function(){
#     visible = $("#pm_containerdfa20370").is(':visible');
#     $("#pm_containerdfa20370").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %%
cities = [
    ('Exeter',50.7184,-3.5339),
    ('Truro',50.2632,-5.051),
    ('Carmarthen',51.8576,-4.3121),
    ('Norwich',52.6309,1.2974),
    ('Brighton And Hove',50.8225,-0.1372),
    ('Bristol',51.44999778,-2.583315472),
    ('Durham',54.7753,-1.5849),
    ('Llanidloes',52.4135,-3.5883),
    ('Penrith',54.6641,-2.7527),
    ('Jedburgh',55.4777,-2.5549),
    ('Coventry',52.42040367,-1.499996583),
    ('Edinburgh',55.94832786,-3.219090618),
    ('Cambridge',52.2053,0.1218),
    ('Glasgow',55.87440472,-4.250707236),
    ('Kingston upon Hull',53.7457,-0.3367),
    ('Leeds',53.83000755,-1.580017539),
    ('London',51.49999473,-0.116721844),
    ('Manchester',53.50041526,-2.247987103),
    ('Nottingham',52.97034426,-1.170016725),
    ('Aberdeen',57.1497,-2.0943),
    ('Fort Augustus',57.1448,-4.6805),
    ('Lairg',58.197,-4.6173),
    ('Oxford',51.7517,-1.2553),
    ('Inverey',56.9855,-3.5055),
    ('Shrewsbury',52.7069,-2.7527),
    ('Colwyn Bay',53.2932,-3.7276),
    ('Newton Stewart',54.9186,-4.5918),    
    ('Portsmouth',50.80034751,-1.080022218)]   

icons=[]
temps=[]
for city in cities:
    lat = city[1]
    lon = city[2]
    line='https://'+username+':'+password+'@twcservice.mybluemix.net/api/weather/v1/geocode/'+str(lat)+'/'+str(lon)+'/observations.json?&units=m'
    r=requests.get(line)
    weather = json.loads(r.text)    
    icons=np.append(icons,weather['observation']['wx_icon'])    
    temps=np.append(temps,weather['observation']['temp'])
# Out:
# <div id="pm_overallContainer99f4633b" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie99f4633b" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName99f4633b"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress99f4633b" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container99f4633b" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors99f4633b">
#     </ul>
#     <div class="tab-content" id="tabContent99f4633b">
#     </div>
# </div>
#
# <script>
# $("#twistie99f4633b").click(function(){
#     visible = $("#pm_container99f4633b").is(':visible');
#     $("#pm_container99f4633b").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %%
dfmap = pd.DataFrame(cities, columns=['city','lat','lon'])    
dfmap['temp']=temps
dfmap['icon']=icons
dfmap.head()
# Out:
# <div id="pm_overallContainerf1936859" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistief1936859" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobNamef1936859"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgressf1936859" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_containerf1936859" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitorsf1936859">
#     </ul>
#     <div class="tab-content" id="tabContentf1936859">
#     </div>
# </div>
#
# <script>
# $("#twistief1936859").click(function(){
#     visible = $("#pm_containerf1936859").is(':visible');
#     $("#pm_containerf1936859").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>
#                 city      lat     lon  temp  icon
# 0             Exeter  50.7184 -3.5339   8.0  None
# 1              Truro  50.2632 -5.0510  11.0    28
# 2         Carmarthen  51.8576 -4.3121   9.0    28
# 3            Norwich  52.6309  1.2974   9.0    30
# 4  Brighton And Hove  50.8225 -0.1372  11.0  None

# %%
from mpl_toolkits.basemap import Basemap
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from matplotlib._png import read_png
from itertools import izip
import urllib

matplotlib.style.use('bmh')
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 12))

# background maps
m1 = Basemap(projection='mill',resolution=None,llcrnrlon=-7.5,llcrnrlat=49.84,urcrnrlon=2.5,urcrnrlat=59,ax=axes[0])
m1.drawlsmask(land_color='dimgrey',ocean_color='dodgerBlue',lakes=True)

m2 = Basemap(projection='mill',resolution=None,llcrnrlon=-7.5,llcrnrlat=49.84,urcrnrlon=2.5,urcrnrlat=59,ax=axes[1])
m2.drawlsmask(land_color='dimgrey',ocean_color='dodgerBlue',lakes=True)

# weather icons map
for [icon,city] in izip(icons,cities):
    lat = city[1]
    lon = city[2]
    try:
        pngfile=urllib.urlopen('https://github.com/ibm-cds-labs/python-notebooks/blob/master/weathericons/icon'+str(int(icon))+'.png?raw=true')
        icon_hand = read_png(pngfile)
        imagebox = OffsetImage(icon_hand, zoom=.15)
        ab = AnnotationBbox(imagebox,m1(lon,lat),frameon=False) 
        axes[0].add_artist(ab)
    except:
        pass
        
# temperature map    
for [temp,city] in izip(temps,cities):
    lat = city[1]
    lon = city[2]
    if temp>8: 
        col='indigo'
    elif temp>10:
        col='darkmagenta'
    elif temp>8:
        col='red'
    elif temp>6:
        col='tomato'
    elif temp>4:
        col='turquoise'
            
    x1, y1 = m2(lon,lat)
    bbox_props = dict(boxstyle="round,pad=0.3", fc=col, ec=col, lw=2)
    axes[1].text(x1, y1, temp, ha="center", va="center",
                size=11,bbox=bbox_props)
    
plt.tight_layout()
# Out:
# <div id="pm_overallContainer4c07db3c" style="display:none">
#     <table width="100%" style="border:0px">
#         <tr style="border:0px">
#             <td width="20px" style="border:0px"><span id="twistie4c07db3c" style="color:blue;font-size:x-large;cursor:pointer">&#9656;</span></td>
#             <td width="130px" style="text-align:left;border:0px"><span id="pm_overallJobName4c07db3c"></span>:</td>
#             <td width="calc(100% - 150px)" style="border:0px"><progress id="pm_overallProgress4c07db3c" max="100" value="0" style="width:100%"></progress></td>
#         </tr>
#     </table>
# </div>
# <div id="pm_container4c07db3c" style="display:none">
#     <ul class="nav nav-tabs" id="progressMonitors4c07db3c">
#     </ul>
#     <div class="tab-content" id="tabContent4c07db3c">
#     </div>
# </div>
#
# <script>
# $("#twistie4c07db3c").click(function(){
#     visible = $("#pm_container4c07db3c").is(':visible');
#     $("#pm_container4c07db3c").slideToggle("slow");
#     $(this).html(visible?"&#9656;":"&#9662;")
# });
# </script>

# %% [markdown]
# ## 5. Plot data with PixieDust

# %%
display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
display(dfmap)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
